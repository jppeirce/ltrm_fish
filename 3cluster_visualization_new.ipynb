# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import fcluster, linkage

# %%
# Load CSV files\
df_data = pd.read_csv('pandas/df_data.csv', low_memory=False)
df_filtered = pd.read_csv('pandas/df_filtered.csv')

agg_df_cluster1 = pd.read_csv('pandas/agg_df_cluster1.csv')
fish_df_cluster1 = pd.read_csv('pandas/fish_df_cluster1.csv')

# %%
# designate which clustering to analyze
df_explore = agg_df_cluster1 # agg_df or agg_df_large or agg_df_top2
fish_explore = fish_df_cluster1 # fish_df or fish_df_large or fish_df_top2

# %%
# Summary of clusters
cluster_summary = df_explore.groupby('cluster').size().sort_values(ascending=False)
print(f"\nCluster sizes:")
print(cluster_summary.head(30))

# Filter to only clusters 1-20
clusters_to_show = range(1, 21)
cluster_summary_filtered = cluster_summary[cluster_summary.index.isin(clusters_to_show)].sort_index()

# Visualize cluster size distribution
plt.figure(figsize=(12, 5))
cluster_summary_filtered.plot(kind='bar')
plt.xlabel('Cluster ID')
plt.ylabel('Number of Samples')
plt.title('Cluster Sizes (Clusters 1-20)')
plt.xticks(rotation=45);
# Out:
# Cluster sizes:
# cluster
# 1     688
# 2     520
# 3     405
# 4     125
# 5      94
# 6      92
# 7      39
# 8      33
# 9      31
# 11     18
# 10     18
# 12     15
# 13     12
# 14     12
# 15     11
# 16     11
# 17     11
# 18     10
# 19     10
# 22      9
# 21      9
# 20      9
# 24      8
# 23      8
# 25      7
# 26      7
# 27      7
# 28      7
# 29      7
# 31      6
# dtype: int64

# %%
# Proportion of samples in each cluster

cluster_counts = df_explore['cluster'].value_counts().sort_index()
cluster_proportion = cluster_counts / cluster_counts.sum()

print("Cluster proportions:")
# robustly select clusters with numeric id < 6
idx_num = pd.to_numeric(cluster_proportion.index, errors='coerce')
print(cluster_proportion[idx_num < 8].round(4))
# Out:
# Cluster proportions:
# cluster
# 1    0.2881
# 2    0.2178
# 3    0.1696
# 4    0.0523
# 5    0.0394
# 6    0.0385
# 7    0.0163
# Name: count, dtype: float64

# %% [markdown]
# # Cluster Species Composition
#
# We next inspected how each cluster varied in it’s species composition.
#
# We will produce three vertical heatmaps for the Jaccard clustering method. Each heatmap shows the average percent presence of each fish species (rows) within each cluster (columns).
#
# *What the graph means:*
#
# -   **Columns**: Each column is a cluster of assemblages (sites grouped by fish community similarity).
# -   **Rows**: Each row is a fish species (only those present in >10% of any cluster).
# -   **Cell values**: The number in each cell is the percent of assemblages in that cluster where the species is present (0–100%).
# -   **Color**: Darker blue = higher percent presence.
# -   **Interpretation**: You can see which species are common or rare in each cluster, and how species composition differs between clusters and clustering methods.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("white")
sns.set_context("notebook", font_scale=1.0)

# Order species by overall frequency of occurrence (sum across columns)
species_cols = [c for c in fish_explore.columns if c != 'cluster']
species_order = fish_explore[species_cols].sum(axis=0).sort_values(ascending=False).index.tolist()

# Keep only top 20 most common species
fishcode_2_include = 41
top_species = species_order[:fishcode_2_include]

# Compute percent presence per cluster for top 20 species only
# Result: rows = cluster, cols = species
jac_comp = fish_explore.groupby('cluster')[top_species].mean() * 100

# Order clusters by overall sample count (so columns are in meaningful order)
# Filter clusters with size >= 10
# 4 cluster size > 160
# 8 cluster size > 30
cluster_filter = 30
cluster_sizes = df_explore['cluster'].value_counts()
cluster_sizes = cluster_sizes[cluster_sizes >= cluster_filter]
cluster_order = [c for c in cluster_sizes.index if c in jac_comp.index]
jac_comp = jac_comp.reindex(cluster_order)

# Transpose so rows=species, cols=cluster (more natural for reading species)
display_df = jac_comp.T

# Create readable cluster labels with site counts
col_labels = [f"{c}\n({cluster_sizes.get(c,0)} samples)" for c in display_df.columns]

# Plot
fig, ax = plt.subplots(figsize=(max(10, 0.6 * display_df.shape[1]), 0.35 * display_df.shape[0] + 4))
cmap = sns.color_palette("YlGnBu", as_cmap=True)  # perceptually-uniform sequential

sns.heatmap(
    display_df,
    ax=ax,
    cmap=cmap,
    vmin=0,
    vmax=100,
    annot=True,
    fmt=".1f",
    linewidths=0.4,
    linecolor="0.9",
    cbar_kws={"label": "% presence"}
)

ax.set_xticklabels(col_labels, rotation=45, ha="right", fontsize=10)
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=9)
ax.set_xlabel("Cluster (sample count)")
ax.set_ylabel("Species")
ax.set_title(f"Fish Species by Cluster (of sample count {cluster_filter} or larger) — % presence", pad=14)
#ax.set_title(f"Top {fishcode_2_include} Most Common Fish Species by Cluster (of sample count {cluster_filter} or larger) — % presence", pad=14)
plt.tight_layout()
plt.show()
fig.savefig(
    'cluster_species_presence.jpg',
    dpi=300,
    bbox_inches='tight',
    format='jpeg',
    pil_kwargs={'quality': 95, 'optimize': True, 'progressive': True}
)

# %% [markdown]
# # Restrict to the 9 ecologically interprettable clusters (>30 samples)

# %%
min_cluster_size = 90

cluster_counts = df_explore['cluster'].value_counts()
highlight_clusters = cluster_counts[cluster_counts >= min_cluster_size].index
print(f"\nClusters with size >= {min_cluster_size}: {list(highlight_clusters)}")
print(f"Original shape: {df_explore.shape}")
df_explore_filtered = df_explore[df_explore['cluster'].isin(highlight_clusters)]
print(f"Filtered shape: {df_explore_filtered.shape}")
print(f"Difference in samples: {df_explore.shape[0] - df_explore_filtered.shape[0]} ({1-(df_explore.shape[0] - df_explore_filtered.shape[0]) / df_explore.shape[0]:.2%} remaining)")
# Out:
# Clusters with size >= 90: [1, 2, 3, 4, 5, 6]
# Original shape: (2388, 100)
# Filtered shape: (1924, 100)
# Difference in samples: 464 (80.57% remaining)

# %%
import tol_colors as tc

CB_PALETTE = tc.muted
# Fallback colors for clusters > 8
EXTRA_COLORS = ['#44AA99', '#999933', '#882255', '#AA4499']
GREY_COLOR = (0.75, 0.75, 0.75)  # light gray for non-highlighted clusters

# Define pool order for facets (2 columns: row1 = Pool 4s, row2 = Pool 8 & 13)
pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

# =============================================================================
# Data preparation
# =============================================================================
df_plot = df_explore_filtered.copy()

# Set mode_pool as ordered categorical to control facet order
df_plot['mode_pool'] = pd.Categorical(
    df_plot['mode_pool'],
    categories=pool_order,
    ordered=True
)

cluster_sizes = df_plot['cluster'].value_counts()
unique_clusters = sorted(df_plot['cluster'].unique())

# =============================================================================
# Build color map: use consistent CB colors, grey out non-highlighted clusters
# =============================================================================

color_map = {}
highlight_idx = 0
highlight_set = set(highlight_clusters)

for cluster_id in unique_clusters:
    if cluster_id not in highlight_set:
        color_map[cluster_id] = GREY_COLOR
    else:
        if highlight_idx < len(CB_PALETTE):
            color_map[cluster_id] = CB_PALETTE[highlight_idx]
        else:
            extra_color_idx = (highlight_idx - len(CB_PALETTE)) % len(EXTRA_COLORS)
            color_map[cluster_id] = EXTRA_COLORS[extra_color_idx]
        highlight_idx += 1

# %%
g = sns.FacetGrid(
    df_plot,
    col="mode_pool",
    hue="cluster",
    palette=color_map,
    col_wrap=2,
    height=5,
    sharex=False,
    sharey=False
)
g.map_dataframe(sns.scatterplot, x="utm_e", y="utm_n", alpha=0.7, s=40)

# Format axes in thousands
for ax in g.axes.flat:
    ax.tick_params(axis='x', rotation=45)
    ax.xaxis.set_major_locator(plt.MaxNLocator(nbins=5))
    ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x/1000:.0f}'))
    ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, p: f'{y/1000:.0f}'))

g.set_axis_labels("UTM Easting (×1000)", "UTM Northing (×1000)")

# Add legend positioned closer to the plots
g.add_legend(title="Cluster", bbox_to_anchor=(1.0, 0.5), loc='center left')

if highlight_clusters is not None and len(highlight_clusters) > 0:
    clusters_str = ', '.join(map(str, highlight_clusters))
    title_suffix = f" (highlighting clusters: {clusters_str})"
else:
    title_suffix = ""
g.figure.suptitle(f"Assemblage Locations by Cluster and Pool{title_suffix}", fontsize=16)

# Adjust layout with more bottom space for rotated labels and proper right margin
g.figure.subplots_adjust(right=0.9, bottom=0.15, top=0.90, hspace=0.25, wspace=0.25)

plt.show()

# %% [markdown]
# ## Clusters over time

# %%
cluster_time = df_explore.groupby(['year', 'cluster']).size().reset_index(name='count')
total_per_year = cluster_time.groupby('year')['count'].transform('sum')
cluster_time['proportion'] = cluster_time['count'] / total_per_year
cluster_time['cluster'] = cluster_time['cluster'].astype(str)
# Filter to only highlighted clusters
cluster_time_filtered = cluster_time[cluster_time['cluster'].isin(highlight_clusters)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize
from scipy.stats import f as f_dist
from plotnine import *

# =====================================================================
# DATA PREPARATION (unchanged)
# =====================================================================

# Calculate proportion of samples in each cluster per year
cluster_time = df_explore.groupby(['year', 'cluster']).size().reset_index(name='count')
total_per_year = cluster_time.groupby('year')['count'].transform('sum')
cluster_time['proportion'] = cluster_time['count'] / total_per_year
cluster_time['cluster'] = cluster_time['cluster'].astype(str)

# Calculate proportion per year per cluster per pool.
# unstack('cluster', fill_value=0) creates one column per cluster and fills
# missing (year, pool, cluster) combinations with 0; stack() returns to long
# form. Result: every cluster absent from a SAMPLED pool-year becomes an
# explicit count = 0 (proportion = 0). Pool-years that were never sampled
# stay absent (no denominator -> proportion genuinely undefined).
cluster_time_pool = (
    df_explore
    .groupby(['year', 'mode_pool', 'cluster'])
    .size()
    .unstack('cluster', fill_value=0)
    .stack()
    .reset_index(name='count')
)

total_per_year_pool = cluster_time_pool.groupby(['year', 'mode_pool'])['count'].transform('sum')
cluster_time_pool['proportion'] = cluster_time_pool['count'] / total_per_year_pool
cluster_time_pool['cluster'] = cluster_time_pool['cluster'].astype(str)

# Sanity check: the zero-fill MUST have produced explicit count == 0 rows.
# If this fails, an old data-prep cell is overwriting cluster_time_pool.
assert (cluster_time_pool['count'] == 0).any(), \
    "zero-fill did not run -- check notebook cell order / stale definitions"

# Filter out a cluster and plot with labels, smoothing only for groups with >= 2 points
#grp_size2 = cluster_time_pool.groupby(['mode_pool', 'cluster'])['year'].transform('size')
#filtered_smooth = cluster_time_pool[grp_size2 >= 2]

# ensure desired pool order and filter to clusters < 5
desired_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

cluster_filter = highlight_clusters
cluster_time_pool_filtered = cluster_time_pool[cluster_time_pool['cluster'].astype(int).isin(cluster_filter)].copy()

cluster_time_pool_filtered['mode_pool'] = pd.Categorical(cluster_time_pool_filtered['mode_pool'], categories=desired_order, ordered=True)

# =====================================================================
# SEGMENTED REGRESSION FOR ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

def piecewise_linear(x, x0, y0, m1, m2):
    """
    Continuous piecewise linear function with breakpoint at x0.
    Left  (x <= x0): y = y0 + m1*(x - x0)
    Right (x >  x0): y = y0 + m2*(x - x0)

    Written with np.maximum instead of np.piecewise so the function is
    differentiable w.r.t. x0 -- curve_fit's numerical Jacobian is reliable.
    """
    return y0 + m1 * (x - x0) + (m2 - m1) * np.maximum(0.0, x - x0)


def fit_segmented_regression(years, proportions, min_points=6, min_nonzero=4, edge_frac=0.15):
    """
    Fit continuous segmented regression with one breakpoint using curve_fit.

    Parameters
    ----------
    min_points : int
        Minimum number of yearly observations required. With zero-filled
        data every cluster in a pool has the same number of points (one per
        sampled pool-year), so this effectively requires the pool to have
        been sampled in >= min_points distinct years.
    min_nonzero : int
        Minimum number of nonzero proportions required. Zero-filling creates
        many near-all-zero series for rare clusters; fitting a 4-parameter
        piecewise model to those is degenerate, so skip them.

    Returns
    -------
    dict with fit results or None if insufficient data
    """
    years = np.asarray(years, dtype=float)
    proportions = np.asarray(proportions, dtype=float)

    if len(years) < min_points:
        return None

    # Guard against degenerate series introduced by zero-filling:
    # too few nonzero points, or an essentially constant series.
    if np.count_nonzero(proportions) < min_nonzero:
        return None
    if np.ptp(proportions) == 0:
        return None

    yr_min, yr_max = years.min(), years.max()
    yr_range = yr_max - yr_min
    if yr_range <= 0:
        return None

    # Keep the breakpoint away from the data extremes so each segment
    # retains a meaningful number of points.
    buf = yr_range * edge_frac
    lo_x0, hi_x0 = yr_min + buf, yr_max - buf

    # Initial guesses
    x0_guess = float(np.clip(np.median(years), lo_x0, hi_x0))
    y0_guess = proportions[np.argmin(np.abs(years - x0_guess))]

    # Initialize slopes from the two data halves so the optimizer has a
    # non-zero gradient signal to move the breakpoint.
    mid = int(np.searchsorted(years, x0_guess))
    if 1 < mid < len(years) - 1:
        m1_guess = np.polyfit(years[:mid], proportions[:mid], 1)[0]
        m2_guess = np.polyfit(years[mid:], proportions[mid:], 1)[0]
    else:
        m1_guess = m2_guess = np.polyfit(years, proportions, 1)[0]

    p0 = [x0_guess, y0_guess, m1_guess, m2_guess]

    # Bounds: breakpoint constrained to the buffered interior range
    bounds = (
        [lo_x0, -np.inf, -np.inf, -np.inf],
        [hi_x0,  np.inf,  np.inf,  np.inf]
    )

    try:
        # Fit piecewise model
        params, cov = optimize.curve_fit(
            piecewise_linear,
            years, proportions,
            p0=p0,
            bounds=bounds,
            maxfev=10000
        )

        x0_fit, y0_fit, m1_fit, m2_fit = params
        y_hat = piecewise_linear(years, *params)
        rss_piece = np.sum((proportions - y_hat) ** 2)

        # Simple linear model for comparison
        slope_simple, intercept_simple = np.polyfit(years, proportions, 1)
        y_hat_simple = slope_simple * years + intercept_simple
        rss_simple = np.sum((proportions - y_hat_simple) ** 2)

        # F-test (nested-model comparison).
        # NOTE: because the breakpoint x0 is a free parameter that is
        # unidentified under the null, this p-value is anti-conservative
        # (Davies problem). Treat it as a screening heuristic, not an
        # exact significance test.
        n = len(years)
        k_piece = 4   # x0, y0, m1, m2
        k_simple = 2

        if n > k_piece and rss_piece > 0 and rss_simple > rss_piece:
            f_stat = ((rss_simple - rss_piece) / (k_piece - k_simple)) / (rss_piece / (n - k_piece))
            p_value = 1 - f_dist.cdf(f_stat, k_piece - k_simple, n - k_piece)
        else:
            # Segmented fit did not improve on simple linear (or too few
            # points) -- F-test is not meaningful.
            f_stat = np.nan
            p_value = np.nan

        return {
            'breakpoint': x0_fit,
            'y_at_break': y0_fit,
            'slope_before': m1_fit,
            'slope_after': m2_fit,
            'rss_piecewise': rss_piece,
            'rss_simple': rss_simple,
            'improvement_pct': 100 * (rss_simple - rss_piece) / rss_simple if rss_simple > 0 else 0,
            'f_stat': f_stat,
            'p_value': p_value,
            'significant': (p_value < 0.05) if not np.isnan(p_value) else False,
            'n_points': n,
            'params': params,
            'cov': cov
        }

    except Exception as e:
        print(f"  Warning: Fit failed - {str(e)}")
        return None


# =====================================================================
# FIT ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

results = []
fitted_data = []

for (pool, cluster), grp in cluster_time_pool_filtered.groupby(['mode_pool', 'cluster'], observed=False):
    # Sort and convert to numpy
    sub = grp[['year', 'proportion']].dropna().sort_values('year')
    years = sub['year'].to_numpy(dtype=float)
    props = sub['proportion'].to_numpy(dtype=float)

    res = fit_segmented_regression(years, props)

    if res:
        # Store results
        results.append({
            'mode_pool': pool,
            'cluster': cluster,
            'breakpoint_year': res['breakpoint'],
            'y_at_breakpoint': res['y_at_break'],
            'slope_before': res['slope_before'],
            'slope_after': res['slope_after'],
            'improvement_pct': res['improvement_pct'],
            'f_statistic': res['f_stat'],
            'p_value': res['p_value'],
            'significant': res['significant'],
            'n_points': res['n_points']
        })
        # Generate fitted values for plotting
        y_fitted = piecewise_linear(years, *res['params'])
        for yr, y_fit in zip(years, y_fitted):
            fitted_data.append({
                'mode_pool': pool,
                'cluster': cluster,
                'year': yr,
                'fitted': y_fit
            })

# Convert to DataFrames
segmented_results_df = pd.DataFrame(results).sort_values(['mode_pool', 'cluster'])
fitted_values_df = pd.DataFrame(fitted_data)

# %%
cluster_time_pool = (
    df_explore
    .groupby(['year', 'mode_pool', 'cluster'])
    .size()
    .unstack('cluster', fill_value=0)
    .stack()
    .reset_index(name='count')
)
cluster_time_pool
# Out:
#       year     mode_pool  cluster  count
# 0     1993  Lower Pool 4        1      0
# 1     1993  Lower Pool 4        2      0
# 2     1993  Lower Pool 4        3      3
# 3     1993  Lower Pool 4        4      2
# 4     1993  Lower Pool 4        5      3
# ...    ...           ...      ...    ...
# 9620  2024  Upper Pool 4       73      0
# 9621  2024  Upper Pool 4       74      0
# 9622  2024  Upper Pool 4       75      0
# 9623  2024  Upper Pool 4       76      0
# 9624  2024  Upper Pool 4       77      0
#
# [9625 rows x 4 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize
from scipy.stats import f as f_dist
from plotnine import *

# Calculate proportion per year per cluster per pool.
# unstack('cluster', fill_value=0) creates one column per cluster and fills
# missing (year, pool, cluster) combinations with 0; stack() returns to long
# form. Result: every cluster absent from a SAMPLED pool-year becomes an
# explicit count = 0 (proportion = 0). Pool-years that were never sampled
# stay absent (no denominator -> proportion genuinely undefined).
cluster_time_pool = (
    df_explore
    .groupby(['year', 'mode_pool', 'cluster'])
    .size()
    .unstack('cluster', fill_value=0)
    .stack()
    .reset_index(name='count')
)

total_per_year_pool = cluster_time_pool.groupby(['year', 'mode_pool'])['count'].transform('sum')
cluster_time_pool['proportion'] = cluster_time_pool['count'] / total_per_year_pool
cluster_time_pool['cluster'] = cluster_time_pool['cluster'].astype(str)
cluster_time_pool_filtered = cluster_time_pool[cluster_time_pool['cluster'].isin(highlight_clusters)].copy()

# Sanity check: the zero-fill MUST have produced explicit count == 0 rows.
# If this fails, an old data-prep cell is overwriting cluster_time_pool.
#assert (cluster_time_pool_filtered['count'] == 0).any(), 
#    "zero-fill did not run -- check notebook cell order / stale definitions"

# Filter out a cluster and plot with labels, smoothing only for groups with >= 2 points
#grp_size2 = cluster_time_pool.groupby(['mode_pool', 'cluster'])['year'].transform('size')
#filtered_smooth = cluster_time_pool[grp_size2 >= 2]

# ensure desired pool order and filter to clusters < 5
desired_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

#cluster_filter = highlight_clusters
#cluster_time_pool_filtered = cluster_time_pool[cluster_time_pool['cluster'].astype(int).isin(cluster_filter)].copy()

cluster_time_pool_filtered['mode_pool'] = pd.Categorical(cluster_time_pool_filtered['mode_pool'], categories=desired_order, ordered=True)

# %%
# =====================================================================
# SEGMENTED REGRESSION FOR ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

def piecewise_linear(x, x0, y0, m1, m2):
    """
    Continuous piecewise linear function with breakpoint at x0.
    Left  (x <= x0): y = y0 + m1*(x - x0)
    Right (x >  x0): y = y0 + m2*(x - x0)

    Written with np.maximum instead of np.piecewise so the function is
    differentiable w.r.t. x0 -- curve_fit's numerical Jacobian is reliable.
    """
    return y0 + m1 * (x - x0) + (m2 - m1) * np.maximum(0.0, x - x0)


def fit_segmented_regression(years, proportions, min_points=6, min_nonzero=4, edge_frac=0.15):
    """
    Fit continuous segmented regression with one breakpoint using curve_fit.

    Parameters
    ----------
    min_points : int
        Minimum number of yearly observations required. With zero-filled
        data every cluster in a pool has the same number of points (one per
        sampled pool-year), so this effectively requires the pool to have
        been sampled in >= min_points distinct years.
    min_nonzero : int
        Minimum number of nonzero proportions required. Zero-filling creates
        many near-all-zero series for rare clusters; fitting a 4-parameter
        piecewise model to those is degenerate, so skip them.

    Returns
    -------
    dict with fit results or None if insufficient data
    """
    years = np.asarray(years, dtype=float)
    proportions = np.asarray(proportions, dtype=float)

    if len(years) < min_points:
        return None

    # Guard against degenerate series introduced by zero-filling:
    # too few nonzero points, or an essentially constant series.
    if np.count_nonzero(proportions) < min_nonzero:
        return None
    if np.ptp(proportions) == 0:
        return None

    yr_min, yr_max = years.min(), years.max()
    yr_range = yr_max - yr_min
    if yr_range <= 0:
        return None

    # Keep the breakpoint away from the data extremes so each segment
    # retains a meaningful number of points.
    buf = yr_range * edge_frac
    lo_x0, hi_x0 = yr_min + buf, yr_max - buf

    # Initial guesses
    x0_guess = float(np.clip(np.median(years), lo_x0, hi_x0))
    y0_guess = proportions[np.argmin(np.abs(years - x0_guess))]

    # Initialize slopes from the two data halves so the optimizer has a
    # non-zero gradient signal to move the breakpoint.
    mid = int(np.searchsorted(years, x0_guess))
    if 1 < mid < len(years) - 1:
        m1_guess = np.polyfit(years[:mid], proportions[:mid], 1)[0]
        m2_guess = np.polyfit(years[mid:], proportions[mid:], 1)[0]
    else:
        m1_guess = m2_guess = np.polyfit(years, proportions, 1)[0]

    p0 = [x0_guess, y0_guess, m1_guess, m2_guess]

    # Bounds: breakpoint constrained to the buffered interior range
    bounds = (
        [lo_x0, -np.inf, -np.inf, -np.inf],
        [hi_x0,  np.inf,  np.inf,  np.inf]
    )

    try:
        # Fit piecewise model
        params, cov = optimize.curve_fit(
            piecewise_linear,
            years, proportions,
            p0=p0,
            bounds=bounds,
            maxfev=10000
        )

        x0_fit, y0_fit, m1_fit, m2_fit = params
        y_hat = piecewise_linear(years, *params)
        rss_piece = np.sum((proportions - y_hat) ** 2)

        # Simple linear model for comparison
        slope_simple, intercept_simple = np.polyfit(years, proportions, 1)
        y_hat_simple = slope_simple * years + intercept_simple
        rss_simple = np.sum((proportions - y_hat_simple) ** 2)

        # F-test (nested-model comparison).
        # NOTE: because the breakpoint x0 is a free parameter that is
        # unidentified under the null, this p-value is anti-conservative
        # (Davies problem). Treat it as a screening heuristic, not an
        # exact significance test.
        n = len(years)
        k_piece = 4   # x0, y0, m1, m2
        k_simple = 2

        if n > k_piece and rss_piece > 0 and rss_simple > rss_piece:
            f_stat = ((rss_simple - rss_piece) / (k_piece - k_simple)) / (rss_piece / (n - k_piece))
            p_value = 1 - f_dist.cdf(f_stat, k_piece - k_simple, n - k_piece)
        else:
            # Segmented fit did not improve on simple linear (or too few
            # points) -- F-test is not meaningful.
            f_stat = np.nan
            p_value = np.nan

        return {
            'breakpoint': x0_fit,
            'y_at_break': y0_fit,
            'slope_before': m1_fit,
            'slope_after': m2_fit,
            'rss_piecewise': rss_piece,
            'rss_simple': rss_simple,
            'improvement_pct': 100 * (rss_simple - rss_piece) / rss_simple if rss_simple > 0 else 0,
            'f_stat': f_stat,
            'p_value': p_value,
            'significant': (p_value < 0.05) if not np.isnan(p_value) else False,
            'n_points': n,
            'params': params,
            'cov': cov
        }

    except Exception as e:
        print(f"  Warning: Fit failed - {str(e)}")
        return None


# =====================================================================
# FIT ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

results = []
fitted_data = []

for (pool, cluster), grp in cluster_time_pool_filtered.groupby(['mode_pool', 'cluster'], observed=False):
    # Sort and convert to numpy
    sub = grp[['year', 'proportion']].dropna().sort_values('year')
    years = sub['year'].to_numpy(dtype=float)
    props = sub['proportion'].to_numpy(dtype=float)

    res = fit_segmented_regression(years, props)

    if res:
        # Store results
        results.append({
            'mode_pool': pool,
            'cluster': cluster,
            'breakpoint_year': res['breakpoint'],
            'y_at_breakpoint': res['y_at_break'],
            'slope_before': res['slope_before'],
            'slope_after': res['slope_after'],
            'improvement_pct': res['improvement_pct'],
            'f_statistic': res['f_stat'],
            'p_value': res['p_value'],
            'significant': res['significant'],
            'n_points': res['n_points']
        })
        # Generate fitted values for plotting
        y_fitted = piecewise_linear(years, *res['params'])
        for yr, y_fit in zip(years, y_fitted):
            fitted_data.append({
                'mode_pool': pool,
                'cluster': cluster,
                'year': yr,
                'fitted': y_fit
            })

# Convert to DataFrames
segmented_results_df = pd.DataFrame(results).sort_values(['mode_pool', 'cluster'])
fitted_values_df = pd.DataFrame(fitted_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 180
#     176                 'fitted': y_fit
#     177             })
#     178
#     179 # Convert to DataFrames
# --> 180 segmented_results_df = pd.DataFrame(results).sort_values(['mode_pool', 'cluster'])
#     181 fitted_values_df = pd.DataFrame(fitted_data)
#
# File ~/Documents/research/ltrm_fish/.venv/lib/python3.14/site-packages/pandas/core/frame.py:8351, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8347             else:
#    8348                 # error: Argument 1 to "list" has incompatible type
#    8349                 # "Generator[ExtensionArray | ndarray[Any, Any], None, None]";
#    8350                 # expected "Iterable[Series]"
# -> 8351                 keys_data = list(keys)  # type: ignore[arg-type]
#    8352
# ...

# %%
# =====================================================================
# SEGMENTED REGRESSION FOR ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

def piecewise_linear(x, x0, y0, m1, m2):
    """
    Continuous piecewise linear function with breakpoint at x0.
    Left  (x <= x0): y = y0 + m1*(x - x0)
    Right (x >  x0): y = y0 + m2*(x - x0)

    Written with np.maximum instead of np.piecewise so the function is
    differentiable w.r.t. x0 -- curve_fit's numerical Jacobian is reliable.
    """
    return y0 + m1 * (x - x0) + (m2 - m1) * np.maximum(0.0, x - x0)


def fit_segmented_regression(years, proportions, min_points=6, min_nonzero=4, edge_frac=0.15):
    """
    Fit continuous segmented regression with one breakpoint using curve_fit.

    Parameters
    ----------
    min_points : int
        Minimum number of yearly observations required. With zero-filled
        data every cluster in a pool has the same number of points (one per
        sampled pool-year), so this effectively requires the pool to have
        been sampled in >= min_points distinct years.
    min_nonzero : int
        Minimum number of nonzero proportions required. Zero-filling creates
        many near-all-zero series for rare clusters; fitting a 4-parameter
        piecewise model to those is degenerate, so skip them.

    Returns
    -------
    dict with fit results or None if insufficient data
    """
    years = np.asarray(years, dtype=float)
    proportions = np.asarray(proportions, dtype=float)

    if len(years) < min_points:
        return None

    # Guard against degenerate series introduced by zero-filling:
    # too few nonzero points, or an essentially constant series.
    if np.count_nonzero(proportions) < min_nonzero:
        return None
    if np.ptp(proportions) == 0:
        return None

    yr_min, yr_max = years.min(), years.max()
    yr_range = yr_max - yr_min
    if yr_range <= 0:
        return None

    # Keep the breakpoint away from the data extremes so each segment
    # retains a meaningful number of points.
    buf = yr_range * edge_frac
    lo_x0, hi_x0 = yr_min + buf, yr_max - buf

    # Initial guesses
    x0_guess = float(np.clip(np.median(years), lo_x0, hi_x0))
    y0_guess = proportions[np.argmin(np.abs(years - x0_guess))]

    # Initialize slopes from the two data halves so the optimizer has a
    # non-zero gradient signal to move the breakpoint.
    mid = int(np.searchsorted(years, x0_guess))
    if 1 < mid < len(years) - 1:
        m1_guess = np.polyfit(years[:mid], proportions[:mid], 1)[0]
        m2_guess = np.polyfit(years[mid:], proportions[mid:], 1)[0]
    else:
        m1_guess = m2_guess = np.polyfit(years, proportions, 1)[0]

    p0 = [x0_guess, y0_guess, m1_guess, m2_guess]

    # Bounds: breakpoint constrained to the buffered interior range
    bounds = (
        [lo_x0, -np.inf, -np.inf, -np.inf],
        [hi_x0,  np.inf,  np.inf,  np.inf]
    )

    try:
        # Fit piecewise model
        params, cov = optimize.curve_fit(
            piecewise_linear,
            years, proportions,
            p0=p0,
            bounds=bounds,
            maxfev=10000
        )

        x0_fit, y0_fit, m1_fit, m2_fit = params
        y_hat = piecewise_linear(years, *params)
        rss_piece = np.sum((proportions - y_hat) ** 2)

        # Simple linear model for comparison
        slope_simple, intercept_simple = np.polyfit(years, proportions, 1)
        y_hat_simple = slope_simple * years + intercept_simple
        rss_simple = np.sum((proportions - y_hat_simple) ** 2)

        # F-test (nested-model comparison).
        # NOTE: because the breakpoint x0 is a free parameter that is
        # unidentified under the null, this p-value is anti-conservative
        # (Davies problem). Treat it as a screening heuristic, not an
        # exact significance test.
        n = len(years)
        k_piece = 4   # x0, y0, m1, m2
        k_simple = 2

        if n > k_piece and rss_piece > 0 and rss_simple > rss_piece:
            f_stat = ((rss_simple - rss_piece) / (k_piece - k_simple)) / (rss_piece / (n - k_piece))
            p_value = 1 - f_dist.cdf(f_stat, k_piece - k_simple, n - k_piece)
        else:
            # Segmented fit did not improve on simple linear (or too few
            # points) -- F-test is not meaningful.
            f_stat = np.nan
            p_value = np.nan

        return {
            'breakpoint': x0_fit,
            'y_at_break': y0_fit,
            'slope_before': m1_fit,
            'slope_after': m2_fit,
            'rss_piecewise': rss_piece,
            'rss_simple': rss_simple,
            'improvement_pct': 100 * (rss_simple - rss_piece) / rss_simple if rss_simple > 0 else 0,
            'f_stat': f_stat,
            'p_value': p_value,
            'significant': (p_value < 0.05) if not np.isnan(p_value) else False,
            'n_points': n,
            'params': params,
            'cov': cov
        }

    except Exception as e:
        print(f"  Warning: Fit failed - {str(e)}")
        return None


# =====================================================================
# FIT ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

results = []
fitted_data = []

for (pool, cluster), grp in cluster_time_pool_filtered.groupby(['mode_pool', 'cluster'], observed=False):
    # Sort and convert to numpy
    sub = grp[['year', 'proportion']].dropna().sort_values('year')
    years = sub['year'].to_numpy(dtype=float)
    props = sub['proportion'].to_numpy(dtype=float)

    res = fit_segmented_regression(years, props)

    if res:
        # Store results
        results.append({
            'mode_pool': pool,
            'cluster': cluster,
            'breakpoint_year': res['breakpoint'],
            'y_at_breakpoint': res['y_at_break'],
            'slope_before': res['slope_before'],
            'slope_after': res['slope_after'],
            'improvement_pct': res['improvement_pct'],
            'f_statistic': res['f_stat'],
            'p_value': res['p_value'],
            'significant': res['significant'],
            'n_points': res['n_points']
        })
        # Generate fitted values for plotting
        y_fitted = piecewise_linear(years, *res['params'])
        for yr, y_fit in zip(years, y_fitted):
            fitted_data.append({
                'mode_pool': pool,
                'cluster': cluster,
                'year': yr,
                'fitted': y_fit
            })

# Convert to DataFrames
segmented_results_df = pd.DataFrame(results).sort_values(['mode_pool', 'cluster'])
fitted_values_df = pd.DataFrame(fitted_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 180
#     176                 'fitted': y_fit
#     177             })
#     178
#     179 # Convert to DataFrames
# --> 180 segmented_results_df = pd.DataFrame(results).sort_values(['mode_pool', 'cluster'])
#     181 fitted_values_df = pd.DataFrame(fitted_data)
#
# File ~/Documents/research/ltrm_fish/.venv/lib/python3.14/site-packages/pandas/core/frame.py:8351, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8347             else:
#    8348                 # error: Argument 1 to "list" has incompatible type
#    8349                 # "Generator[ExtensionArray | ndarray[Any, Any], None, None]";
#    8350                 # expected "Iterable[Series]"
# -> 8351                 keys_data = list(keys)  # type: ignore[arg-type]
#    8352
# ...

# %%
# Build plotting data
annotated_data = cluster_time_pool_filtered.merge(
    segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year', 'significant',
                          'y_at_breakpoint', 'slope_before', 'slope_after']],
    on=['mode_pool', 'cluster'],
    how='left'
).copy()

# Keep types consistent for plotting
annotated_data['cluster'] = annotated_data['cluster'].astype(str)
segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(str)

# Set ordered pool categories
annotated_data['mode_pool'] = pd.Categorical(
    annotated_data['mode_pool'],
    categories=desired_order,
    ordered=True
)

# One breakpoint row per pool-cluster (prevents over-plotting vlines)
breakpoint_data = (
    annotated_data[['mode_pool', 'cluster', 'breakpoint_year']]
    .dropna(subset=['breakpoint_year'])
    .drop_duplicates()
    .copy()
)

# Year bounds per pool-cluster
year_bounds = (
    annotated_data.groupby(['mode_pool', 'cluster'], observed=False)['year']
    .agg(year_min='min', year_max='max')
    .reset_index()
)

# Build exactly two fitted segments per pool-cluster
seg_base = (
    segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year',
                          'y_at_breakpoint', 'slope_before', 'slope_after']]
    .merge(year_bounds, on=['mode_pool', 'cluster'], how='inner')
    .dropna(subset=['breakpoint_year'])
    .copy()
)

# Keep breakpoint inside observed year range
seg_base['bp'] = seg_base['breakpoint_year'].clip(seg_base['year_min'], seg_base['year_max'])

# Segment 1: year_min -> breakpoint
seg1 = seg_base.copy()
seg1['x'] = seg1['year_min']
seg1['xend'] = seg1['bp']
seg1['y'] = seg1['y_at_breakpoint'] + seg1['slope_before'] * (seg1['x'] - seg1['bp'])
seg1['yend'] = seg1['y_at_breakpoint']

# Segment 2: breakpoint -> year_max
seg2 = seg_base.copy()
seg2['x'] = seg2['bp']
seg2['xend'] = seg2['year_max']
seg2['y'] = seg2['y_at_breakpoint']
seg2['yend'] = seg2['y_at_breakpoint'] + seg2['slope_after'] * (seg2['xend'] - seg2['bp'])

segments_df = pd.concat([
    seg1[['mode_pool', 'cluster', 'x', 'xend', 'y', 'yend']],
    seg2[['mode_pool', 'cluster', 'x', 'xend', 'y', 'yend']]
], ignore_index=True)

segments_df['mode_pool'] = pd.Categorical(
    segments_df['mode_pool'],
    categories=desired_order,
    ordered=True
)
breakpoint_data['mode_pool'] = pd.Categorical(
    breakpoint_data['mode_pool'],
    categories=desired_order,
    ordered=True
)

# Plot
p = (
    ggplot(annotated_data, aes(x='year', y='proportion', color='cluster')) +
    geom_point(size=1.5, alpha=0.65) +
    geom_segment(
        data=segments_df,
        mapping=aes(x='x', y='y', xend='xend', yend='yend', color='cluster'),
        inherit_aes=False,
        size=1.1,
        alpha=0.9
    ) +
    geom_vline(
        data=breakpoint_data,
        mapping=aes(xintercept='breakpoint_year', color='cluster'),
        linetype='dashed',
        alpha=0.55,
        size=0.6
    ) +
    facet_wrap('~mode_pool', ncol=1) +
    scale_x_continuous(minor_breaks=range(1993, 2024, 1), breaks=range(1993, 2024, 5)) +
    scale_y_continuous(breaks=np.arange(0.0, 1.01, 0.2)) +
    scale_color_manual(values=CB_PALETTE) +
    labs(
        x='Year',
        y='Proportion of Samples',
        color='Cluster',
        title='Segmented Regression (dashed line = breakpoint)'
    ) +
    theme_bw() +
    theme(figure_size=(8, 8))
)

p.save('segmented_regression_clusters.jpg', dpi=300, verbose=False)
p.show()
# Out:
# ---------------------------------------------------------------------------
# PlotnineError                             Traceback (most recent call last)
# Cell In[16], line 109
#     105     theme_bw() +
#     106     theme(figure_size=(8, 8))
#     107 )
#     108
# --> 109 p.save('segmented_regression_clusters.jpg', dpi=300, verbose=False)
#     110 p.show()
#
# File ~/Documents/research/ltrm_fish/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:681, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     632 def save(
#     633     self,
#     634     filename: Optional[str | Path | BytesIO] = None,
#    (...)    643     **kwargs: Any,
#     644 ):
#     645     """
#     646     Save a ggplot object as an image file
#     647
#    (...)    679         Additional arguments to pass to matplotlib `savefig()`.
#     680     """
# --> 681     sv = self.save_helper(
#     682         filename=filename,
# ...

# %%
# Create formatted table with F-stat and p-value
stats_table = segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year', 
                                     'f_statistic', 'p_value']].copy()

stats_table['breakpoint_year'] = stats_table['breakpoint_year'].astype(int)
stats_table['f_statistic'] = stats_table['f_statistic'].round(2)
stats_table['p_value'] = stats_table['p_value'].round(4)

# Add significance stars
def get_significance_stars(p_value):
    if p_value < 0.001:
        return '***'
    elif p_value < 0.01:
        return '**'
    elif p_value < 0.05:
        return '*'
    else:
        return ''

stats_table['sig'] = stats_table['p_value'].apply(get_significance_stars)

# Reorder rows to match desired pool order
stats_table['mode_pool'] = pd.Categorical(
    stats_table['mode_pool'], 
    categories=desired_order, 
    ordered=True
)
stats_table = stats_table.sort_values(['mode_pool', 'cluster'])

print("\n" + "=" * 60)
print("SEGMENTED REGRESSION STATISTICS")
print("=" * 60)
print(stats_table.to_string(index=False))
print("\nSignificance: *** p<0.001, ** p<0.01, * p<0.05")
# Out:
# ...
# SEGMENTED REGRESSION STATISTICS
# ...
#    mode_pool cluster  breakpoint_year  f_statistic  p_value sig
# Upper Pool 4       1             1998         1.06   0.3613
# Upper Pool 4       2             2007         0.12   0.8888
# Upper Pool 4       3             2006         0.64   0.5355
# Upper Pool 4       4             2017         0.37   0.6930
# Upper Pool 4       6             2007         0.01   0.9887
# Lower Pool 4       1             2006         1.99   0.1559
# Lower Pool 4       2             2015         0.57   0.5714
# Lower Pool 4       3             2010         2.00   0.1542
# Lower Pool 4       4             2001         4.21   0.0255   *
# Lower Pool 4       5             2018         0.66   0.5262
#       Pool 8       1             1997         5.17   0.0125   *
#       Pool 8       2             2010         0.85   0.4379
#       Pool 8       3             2011         3.55   0.0427   *
#       Pool 8       4             1997         3.27   0.0537
# ...

# %%
# Configuration / safe fallbacks
pool_order = desired_order if 'desired_order' in globals() else ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]
highlight_clusters = highlight_clusters if 'highlight_clusters' in globals() else [1, 2, 3, 4, 5, 6, 7, 8, 9]
CB_PALETTE = tc.muted

# Prepare data
ctp = cluster_time_pool.copy()
try:
    ctp['cluster'] = ctp['cluster'].astype(int)
except Exception:
    pass
ctp['year'] = ctp['year'].astype(int)

cluster_order = highlight_clusters
cluster_colors = {str(c): CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(cluster_order)}

# Ordered categoricals for correct facet/legend order
ctp['mode_pool'] = pd.Categorical(ctp['mode_pool'], categories=pool_order, ordered=True)
ctp['cluster'] = pd.Categorical(ctp['cluster'].astype(str), categories=[str(c) for c in cluster_order], ordered=True)
ctp['year'] = pd.Categorical(ctp['year'].astype(str), categories=sorted(ctp['year'].astype(str).unique()), ordered=True)

p = (
    ggplot(ctp[ctp['mode_pool'].isin(pool_order)], aes(x='year', y='proportion', fill='cluster'))
    + geom_bar(stat='identity', position='stack', width=0.8)
    + facet_wrap('~ mode_pool', ncol=1, scales='fixed')
    + scale_fill_manual(values=cluster_colors, name='Cluster')
    + scale_x_discrete()
    + coord_cartesian(ylim=(0, 1))
    + labs(
        title='Yearly Cluster Proportions (stacked) — Faceted by Pool',
        x='Year',
        y='Proportion of samples'
    )
    + theme_bw()
    + theme(
        axis_text_x=element_text(rotation=45, ha='right'),
        figure_size=(14, 4 * len(pool_order)),
    )
)

ggsave(p, 'stacked_cluster_proportion_by_year_pool.jpg', dpi=300)
p.show()
# Out:
# /var/folders/4d/6pl9k4d15bd44r543fkh_pl0jmttd6/T/ipykernel_69891/1970846665.py:19: Pandas4Warning: Constructing a Categorical with a dtype and values containing non-null entries not in that dtype's categories is deprecated and will raise in a future version.
# /Users/jpeirce/Documents/research/ltrm_fish/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:623: PlotnineWarning: Saving 14 x 16 in image.
# /Users/jpeirce/Documents/research/ltrm_fish/.venv/lib/python3.14/site-packages/plotnine/ggplot.py:624: PlotnineWarning: Filename: stacked_cluster_proportion_by_year_pool.jpg

# %%
cluster_colors
# Out:
# {'1': '#CC6677',
#  '2': '#332288',
#  '3': '#DDCC77',
#  '4': '#117733',
#  '5': '#88CCEE',
#  '6': '#882255',
#  '7': '#44AA99',
#  '8': '#999933',
#  '9': '#AA4499'}

# %% [markdown]
# ## Uncommon clusters (7,8, and 9) graph for supplemental material

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import optimize
from scipy.stats import f as f_dist
from plotnine import *

# =====================================================================
# DATA PREPARATION (unchanged)
# =====================================================================

# Calculate proportion of samples in each cluster per year
cluster_time = df_explore.groupby(['year', 'cluster']).size().reset_index(name='count')
total_per_year = cluster_time.groupby('year')['count'].transform('sum')
cluster_time['proportion'] = cluster_time['count'] / total_per_year
cluster_time['cluster'] = cluster_time['cluster'].astype(str)

# Calculate proportion per year per cluster per pool.
# unstack('cluster', fill_value=0) creates one column per cluster and fills
# missing (year, pool, cluster) combinations with 0; stack() returns to long
# form. Result: every cluster absent from a SAMPLED pool-year becomes an
# explicit count = 0 (proportion = 0). Pool-years that were never sampled
# stay absent (no denominator -> proportion genuinely undefined).
cluster_time_pool = (
    df_explore
    .groupby(['year', 'mode_pool', 'cluster'])
    .size()
    .unstack('cluster', fill_value=0)
    .stack()
    .reset_index(name='count')
)

total_per_year_pool = cluster_time_pool.groupby(['year', 'mode_pool'])['count'].transform('sum')
cluster_time_pool['proportion'] = cluster_time_pool['count'] / total_per_year_pool
cluster_time_pool['cluster'] = cluster_time_pool['cluster'].astype(str)

# Sanity check: the zero-fill MUST have produced explicit count == 0 rows.
# If this fails, an old data-prep cell is overwriting cluster_time_pool.
assert (cluster_time_pool['count'] == 0).any(), \
    "zero-fill did not run -- check notebook cell order / stale definitions"

# Filter out a cluster and plot with labels, smoothing only for groups with >= 2 points
#grp_size2 = cluster_time_pool.groupby(['mode_pool', 'cluster'])['year'].transform('size')
#filtered_smooth = cluster_time_pool[grp_size2 >= 2]

# ensure desired pool order and filter to clusters < 5
desired_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

cluster_filter = [7, 8, 9]
cluster_time_pool_filtered = cluster_time_pool[cluster_time_pool['cluster'].astype(int).isin(cluster_filter)].copy()

annotated_data['cluster'] = annotated_data['cluster'].astype(str)
segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(str)

cluster_time_pool_filtered['mode_pool'] = pd.Categorical(cluster_time_pool_filtered['mode_pool'], categories=desired_order, ordered=True)


# =====================================================================
# FIT ALL POOL-CLUSTER COMBINATIONS
# =====================================================================

results = []
fitted_data = []

for (pool, cluster), grp in cluster_time_pool_filtered.groupby(['mode_pool', 'cluster'], observed=False):
    # Sort and convert to numpy
    sub = grp[['year', 'proportion']].dropna().sort_values('year')
    years = sub['year'].to_numpy(dtype=float)
    props = sub['proportion'].to_numpy(dtype=float)

    res = fit_segmented_regression(years, props)

    if res:
        # Store results
        results.append({
            'mode_pool': pool,
            'cluster': cluster,
            'breakpoint_year': res['breakpoint'],
            'y_at_breakpoint': res['y_at_break'],
            'slope_before': res['slope_before'],
            'slope_after': res['slope_after'],
            'improvement_pct': res['improvement_pct'],
            'f_statistic': res['f_stat'],
            'p_value': res['p_value'],
            'significant': res['significant'],
            'n_points': res['n_points']
        })
        # Generate fitted values for plotting
        y_fitted = piecewise_linear(years, *res['params'])
        for yr, y_fit in zip(years, y_fitted):
            fitted_data.append({
                'mode_pool': pool,
                'cluster': cluster,
                'year': yr,
                'fitted': y_fit
            })

# Convert to DataFrames
segmented_results_df = pd.DataFrame(results).sort_values(['mode_pool', 'cluster'])
fitted_values_df = pd.DataFrame(fitted_data)

# %%
# Build plotting data
annotated_data = cluster_time_pool_filtered.merge(
    segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year', 'significant',
                          'y_at_breakpoint', 'slope_before', 'slope_after']],
    on=['mode_pool', 'cluster'],
    how='left'
).copy()

# Keep types consistent for plotting
annotated_data['cluster'] = annotated_data['cluster'].astype(str)
segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(str)

# Set ordered pool categories
annotated_data['mode_pool'] = pd.Categorical(
    annotated_data['mode_pool'],
    categories=desired_order,
    ordered=True
)

# One breakpoint row per pool-cluster (prevents over-plotting vlines)
breakpoint_data = (
    annotated_data[['mode_pool', 'cluster', 'breakpoint_year']]
    .dropna(subset=['breakpoint_year'])
    .drop_duplicates()
    .copy()
)

# Year bounds per pool-cluster
year_bounds = (
    annotated_data.groupby(['mode_pool', 'cluster'], observed=False)['year']
    .agg(year_min='min', year_max='max')
    .reset_index()
)

# Build exactly two fitted segments per pool-cluster
seg_base = (
    segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year',
                          'y_at_breakpoint', 'slope_before', 'slope_after']]
    .merge(year_bounds, on=['mode_pool', 'cluster'], how='inner')
    .dropna(subset=['breakpoint_year'])
    .copy()
)

# Keep breakpoint inside observed year range
seg_base['bp'] = seg_base['breakpoint_year'].clip(seg_base['year_min'], seg_base['year_max'])

# Segment 1: year_min -> breakpoint
seg1 = seg_base.copy()
seg1['x'] = seg1['year_min']
seg1['xend'] = seg1['bp']
seg1['y'] = seg1['y_at_breakpoint'] + seg1['slope_before'] * (seg1['x'] - seg1['bp'])
seg1['yend'] = seg1['y_at_breakpoint']

# Segment 2: breakpoint -> year_max
seg2 = seg_base.copy()
seg2['x'] = seg2['bp']
seg2['xend'] = seg2['year_max']
seg2['y'] = seg2['y_at_breakpoint']
seg2['yend'] = seg2['y_at_breakpoint'] + seg2['slope_after'] * (seg2['xend'] - seg2['bp'])

segments_df = pd.concat([
    seg1[['mode_pool', 'cluster', 'x', 'xend', 'y', 'yend']],
    seg2[['mode_pool', 'cluster', 'x', 'xend', 'y', 'yend']]
], ignore_index=True)

segments_df['mode_pool'] = pd.Categorical(
    segments_df['mode_pool'],
    categories=desired_order,
    ordered=True
)
breakpoint_data['mode_pool'] = pd.Categorical(
    breakpoint_data['mode_pool'],
    categories=desired_order,
    ordered=True
)

# Plot
p = (
    ggplot(annotated_data, aes(x='year', y='proportion', color='cluster')) +
    geom_point(size=1.5, alpha=0.65) +
    geom_segment(
        data=segments_df,
        mapping=aes(x='x', y='y', xend='xend', yend='yend', color='cluster'),
        inherit_aes=False,
        size=1.1,
        alpha=0.9
    ) +
    geom_vline(
        data=breakpoint_data,
        mapping=aes(xintercept='breakpoint_year', color='cluster'),
        linetype='dashed',
        alpha=0.55,
        size=0.6
    ) +
    facet_wrap('~mode_pool', ncol=1) +
    scale_x_continuous(minor_breaks=range(1993, 2024, 1), breaks=range(1993, 2024, 5)) +
    scale_y_continuous(breaks=np.arange(0.0, 1.01, 0.2)) +
    scale_color_manual(values=cluster_colors) +
    labs(
        x='Year',
        y='Proportion of Samples',
        color='Cluster',
        title='Segmented Regression (dashed line = breakpoint)'
    ) +
    theme_bw() +
    theme(figure_size=(8, 8))
)

p.save('segmented_regression_clusters.jpg', dpi=300, verbose=False)
p.show()

# %% [markdown]
# table of average and variance (over time) of proportion for each cluster and reach

# %%
import tol_colors as tc

# Define clusters to show
highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8,9]

# Define pool order
pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

# Build color palette from tol_colors muted
CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# Filter data to highlight clusters only and exclude 'No breakpoint'
df_plot = df_explore[
    (df_explore['cluster'].isin(highlight_clusters))
].copy()
    
# Calculate proportion of samples in each pool for each cluster
prop_df = (df_plot.groupby(['mode_pool', 'cluster'])
               .size()
               .reset_index(name='count'))
    
# Calculate total samples per pool to get proportions
totals = prop_df.groupby('mode_pool')['count'].transform('sum')
prop_df['proportion'] = prop_df['count'] / totals
    
# Set cluster as categorical with numerical order
prop_df['cluster'] = pd.Categorical(prop_df['cluster'], categories=highlight_clusters, ordered=True)
    
# Create plot
plt.figure(figsize=(8, 6))
sns.barplot(data=prop_df, x='mode_pool', y='proportion', hue='cluster',
            palette=cluster_colors, dodge=True, 
            order=pool_order,
            hue_order=highlight_clusters)
    
plt.xlabel('Pool')
plt.ylabel('Proportion of Samples')
plt.title(f'Proportion of Samples by Pool and Cluster')
plt.legend(title='Cluster', bbox_to_anchor=(1.02, 0.5), loc='center left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
    
# Create filename based on period
filename = "cluster_pool_proportion.jpg"
plt.savefig(
    filename,
    dpi=300,
    bbox_inches='tight',
    format='jpeg',
    pil_kwargs={'quality': 95, 'optimize': True, 'progressive': True}
)
    
plt.show()

# %%
df_plot.head()
# Out:
#     barcode     utm_e      utm_n  year     mode_pool  \
# 0  11000330  578229.0  4915808.0  1993  Lower Pool 4
# 1  11000331  579229.0  4916258.0  1993  Lower Pool 4
# 4  11000334  581880.0  4913658.0  1993  Lower Pool 4
# 5  11000335  580430.0  4911758.0  1993  Lower Pool 4
# 6  11000391  531129.0  4939908.0  1993  Upper Pool 4
#
#                mode_aqua_desc   CNCF   LKSG   PDFH   IODR  ...   SJHR   MMSN  \
# 0  Contiguous Floodplain Lake  False  False  False  False  ...  False  False
# 1  Contiguous Floodplain Lake   True  False  False  False  ...  False  False
# 4  Contiguous Floodplain Lake  False  False  False  False  ...  False  False
# 5  Contiguous Floodplain Lake  False  False  False  False  ...  False  False
# 6                Side Channel  False  False  False  False  ...  False   True
#
#     RKBS   BSMW   TPMT   BRBT   LSSR   BNMW   WTSK  cluster
# 0  False  False  False  False  False  False  False        2
# 1  False  False  False  False  False  False  False        1
# ...

# %%
import tol_colors as tc

# Define clusters to show
highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8, 9]

# Define pool order
# pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

# Build color palette from tol_colors muted
CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# Filter data to highlight clusters only and exclude 'No breakpoint'
df_plot = df_explore[
    (df_explore['cluster'].isin(highlight_clusters))
].copy()
    
# Calculate proportion of samples in each pool for each cluster
prop_df = (df_plot.groupby(['mode_aqua_desc', 'cluster'])
               .size()
               .reset_index(name='count'))
    
# Calculate total samples per pool to get proportions
totals = prop_df.groupby('mode_aqua_desc')['count'].transform('sum')
prop_df['proportion'] = prop_df['count'] / totals
    
# Set cluster as categorical with numerical order
prop_df['cluster'] = pd.Categorical(prop_df['cluster'], categories=highlight_clusters, ordered=True)
    
# Create plot
plt.figure(figsize=(8, 6))
sns.barplot(data=prop_df, x='mode_aqua_desc', y='proportion', hue='cluster',
            palette=cluster_colors, dodge=True, 
 #           order=pool_order,
            hue_order=highlight_clusters)
    
plt.xlabel('Aquatic Description')
plt.ylabel('Proportion of Samples')
plt.title(f'Proportion of Samples by Aquatic Description and Cluster')
plt.legend(title='Cluster', bbox_to_anchor=(1.02, 0.5), loc='center left')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
    
# Create filename based on period
filename = "cluster_aqua_desc_proportion.jpg"
plt.savefig(
    filename,
    dpi=300,
    bbox_inches='tight',
    format='jpeg',
    pil_kwargs={'quality': 95, 'optimize': True, 'progressive': True}
)
    
plt.show()

# %%
# Build a complete year x cluster grid per reach (mode_pool), fill missing proportions with 0,
# then compute mean and variance of proportions over time for each cluster within each reach.
# Filter to only highlight_clusters

# Convert highlight_clusters to strings for comparison
highlight_clusters_str = [str(c) for c in highlight_clusters]

# Ensure we use clusters present at least once per reach
years_by_pool = {
    pool: np.sort(df_explore.loc[df_explore['mode_pool'] == pool, 'year'].unique())
    for pool in df_explore['mode_pool'].unique()
}
clusters_by_pool = {
    pool: sorted(
        [c for c in cluster_time_pool.loc[cluster_time_pool['mode_pool'] == pool, 'cluster'].unique()
         if c in highlight_clusters_str],
        key=int
    )
    for pool in cluster_time_pool['mode_pool'].unique()
}

grid_frames = []
for pool, years in years_by_pool.items():
    clusters = clusters_by_pool.get(pool, [])
    if len(clusters) == 0 or len(years) == 0:
        continue
    grid_frames.append(
        pd.MultiIndex.from_product(
            [[pool], clusters, years],
            names=['mode_pool', 'cluster', 'year']
        ).to_frame(index=False)
    )
full_grid = pd.concat(grid_frames, ignore_index=True)

# Merge with proportions and fill missing with 0 (cluster absent that year)
prop_full = full_grid.merge(
    cluster_time_pool[['mode_pool', 'cluster', 'year', 'proportion']],
    on=['mode_pool', 'cluster', 'year'],
    how='left'
)
prop_full['proportion'] = prop_full['proportion'].fillna(0.0)

# Aggregate mean and variance over time
cluster_proportion_stats = (
    prop_full.groupby(['mode_pool', 'cluster'], observed=False)['proportion']
    .agg(avg='mean', var='var', n_years='size')
    .reset_index()
)

# Order by desired reach order and numeric cluster order
cluster_proportion_stats['mode_pool'] = pd.Categorical(
    cluster_proportion_stats['mode_pool'],
    categories=desired_order,
    ordered=True
)
cluster_proportion_stats['cluster'] = pd.Categorical(
    cluster_proportion_stats['cluster'],
    categories=highlight_clusters_str,
    ordered=True
)
cluster_proportion_stats = cluster_proportion_stats.sort_values(['mode_pool', 'cluster']).reset_index(drop=True)

# Round for readability
cluster_proportion_stats['avg'] = cluster_proportion_stats['avg'].round(4)
cluster_proportion_stats['var'] = cluster_proportion_stats['var'].round(6)

# Print and save
print(f"\nProportion statistics for clusters: {highlight_clusters}")
print(cluster_proportion_stats.to_string(index=False))
cluster_proportion_stats.to_csv('cluster_proportion_stats_highlight.csv', index=False)
# Out:
# Proportion statistics for clusters: [1, 2, 3, 4, 5, 6, 7, 8, 9]
#    mode_pool cluster    avg      var  n_years
# Upper Pool 4       1 0.0488 0.006029       31
# Upper Pool 4       2 0.5419 0.074432       31
# Upper Pool 4       3 0.0313 0.006292       31
# Upper Pool 4       4 0.2689 0.061701       31
# Upper Pool 4       6 0.0217 0.004648       31
# Upper Pool 4       7 0.0685 0.025414       31
# Upper Pool 4       8 0.0153 0.001769       31
# Upper Pool 4       9 0.0036 0.000398       31
# Lower Pool 4       1 0.3932 0.024524       31
# Lower Pool 4       2 0.0881 0.009751       31
# Lower Pool 4       3 0.3043 0.021465       31
# Lower Pool 4       4 0.0271 0.005087       31
# Lower Pool 4       5 0.1128 0.008222       31
# Lower Pool 4       6 0.0067 0.000461       31
# Lower Pool 4       7 0.0062 0.000629       31
# Lower Pool 4       8 0.0403 0.002696       31
# Lower Pool 4       9 0.0213 0.001987       31
#       Pool 8       1 0.5677 0.015089       31
# ...

# %%
# Create a multi-level column table
pivot_combined = cluster_proportion_stats.pivot(
    index='cluster', 
    columns='mode_pool', 
    values=['avg', 'var']
)
# Reorder columns to group by pool
pivot_combined = pivot_combined.swaplevel(axis=1).sort_index(axis=1)

display(pivot_combined.style.format("{:.4f}").background_gradient(cmap='Blues', axis=None))
# Out:
# <style type="text/css">
# #T_c76b0_row0_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_c76b0_row0_col1, #T_c76b0_row2_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_c76b0_row0_col2 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_c76b0_row0_col3, #T_c76b0_row1_col3, #T_c76b0_row6_col2, #T_c76b0_row7_col6 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_c76b0_row0_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_c76b0_row0_col5, #T_c76b0_row1_col7, #T_c76b0_row5_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_c76b0_row0_col6 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_c76b0_row0_col7, #T_c76b0_row1_col0, #T_c76b0_row1_col5, #T_c76b0_row3_col7, #T_c76b0_row7_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# ...

# %%
display(pivot_combined.style.format("{:.4f}"))
pivot_combined.to_html('cluster_proportion_table.html', float_format='{:.4f}'.format)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f0405">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mode_pool</th>
#       <th id="T_f0405_level0_col0" class="col_heading level0 col0" colspan="2">Upper Pool 4</th>
#       <th id="T_f0405_level0_col2" class="col_heading level0 col2" colspan="2">Lower Pool 4</th>
#       <th id="T_f0405_level0_col4" class="col_heading level0 col4" colspan="2">Pool 8</th>
#       <th id="T_f0405_level0_col6" class="col_heading level0 col6" colspan="2">Pool 13</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_f0405_level1_col0" class="col_heading level1 col0" >avg</th>
#       <th id="T_f0405_level1_col1" class="col_heading level1 col1" >var</th>
#       <th id="T_f0405_level1_col2" class="col_heading level1 col2" >avg</th>
#       <th id="T_f0405_level1_col3" class="col_heading level1 col3" >var</th>
#       <th id="T_f0405_level1_col4" class="col_heading level1 col4" >avg</th>
# ...

# %%
# Create formatted table with F-stat and p-value
stats_table = segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year', 
                                     'f_statistic', 'p_value']].copy()

stats_table['breakpoint_year'] = stats_table['breakpoint_year'].astype(int)
stats_table['f_statistic'] = stats_table['f_statistic'].round(2)
stats_table['p_value'] = stats_table['p_value'].round(4)

# Add significance stars
def get_significance_stars(p_value):
    if p_value < 0.001:
        return '***'
    elif p_value < 0.01:
        return '**'
    elif p_value < 0.05:
        return '*'
    else:
        return ''

stats_table['sig'] = stats_table['p_value'].apply(get_significance_stars)

# Reorder rows to match desired pool order
stats_table['mode_pool'] = pd.Categorical(
    stats_table['mode_pool'], 
    categories=desired_order, 
    ordered=True
)
stats_table = stats_table.sort_values(['mode_pool', 'cluster'])

print("\n" + "=" * 60)
print("SEGMENTED REGRESSION STATISTICS")
print("=" * 60)
print(stats_table.to_string(index=False))
print("\nSignificance: *** p<0.001, ** p<0.01, * p<0.05")
# Out:
# ...
# SEGMENTED REGRESSION STATISTICS
# ...
#    mode_pool cluster  breakpoint_year  f_statistic  p_value sig
# Upper Pool 4       1             2007         0.69   0.5130
# Upper Pool 4       3             2002         4.79   0.0188   *
# Upper Pool 4       4             1997         2.14   0.1381
# Upper Pool 4       6             2004         7.43   0.1187
# Lower Pool 4       1             2009         0.11   0.8941
# Lower Pool 4       2             2009         1.83   0.1803
# Lower Pool 4       3             2012         0.15   0.8660
# Lower Pool 4       4             2000       183.87   0.0000 ***
# Lower Pool 4       5             2002         0.25   0.7804
# Lower Pool 4       7             2012         2.65   0.1645
#       Pool 8       1             1996         9.46   0.0007 ***
#       Pool 8       2             2012         1.28   0.2938
#       Pool 8       3             1995         7.26   0.0069  **
#       Pool 8       4             2001         1.91   0.1988
# ...

# %%
# Journal-style summary of segmented regression and before/after composition shifts

# --- 1) Segmented regression summary ---
sr = segmented_results_df.copy()
sr['mode_pool'] = sr['mode_pool'].astype(str)

n_models = len(sr)
n_sig = int(sr['significant'].sum())
pct_sig = 100 * n_sig / n_models if n_models else 0

sig_by_pool = (
    sr.groupby('mode_pool', observed=False)['significant']
      .agg(n_sig='sum', n_models='size')
      .reset_index()
)
sig_by_pool['pct_sig'] = (100 * sig_by_pool['n_sig'] / sig_by_pool['n_models']).round(1)

median_bp_all = float(sr['breakpoint_year'].median())
median_bp_sig = float(sr.loc[sr['significant'], 'breakpoint_year'].median()) if n_sig > 0 else np.nan

# Directional change in slope across breakpoint
sr['direction_before'] = np.sign(sr['slope_before'])
sr['direction_after'] = np.sign(sr['slope_after'])
sr['direction_change'] = sr['direction_before'] != sr['direction_after']
n_dir_change = int(sr['direction_change'].sum())

# Strongest models
top_improve = sr.sort_values('improvement_pct', ascending=False).head(3)[
    ['mode_pool', 'cluster', 'improvement_pct', 'p_value']
]
top_sig = sr[sr['significant']].sort_values('p_value').head(3)[
    ['mode_pool', 'cluster', 'breakpoint_year', 'slope_before', 'slope_after', 'p_value']
]

# --- 2) Before vs after proportion shift summary ---
# wide_df already contains one row per mode_pool-cluster with Before/After proportions
wd = wide_df.copy()
wd['delta_after_minus_before'] = wd['After breakpoint'] - wd['Before breakpoint']

n_increase = int((wd['delta_after_minus_before'] > 0).sum())
n_decrease = int((wd['delta_after_minus_before'] < 0).sum())
n_nochange = int((wd['delta_after_minus_before'] == 0).sum())

largest_increase = wd.sort_values('delta_after_minus_before', ascending=False).head(3)[
    ['mode_pool', 'cluster', 'delta_after_minus_before']
]
largest_decrease = wd.sort_values('delta_after_minus_before', ascending=True).head(3)[
    ['mode_pool', 'cluster', 'delta_after_minus_before']
]

# --- 3) Build professional summary text ---
pool_sig_text = "; ".join(
    f"{r.mode_pool}: {int(r.n_sig)}/{int(r.n_models)} significant ({r.pct_sig:.1f}%)"
    for r in sig_by_pool.itertuples(index=False)
)

top_sig_text = "; ".join(
    f"{r.mode_pool}, cluster {int(r.cluster)} (bp≈{r.breakpoint_year:.1f}, "
    f"slope {r.slope_before:.4f}→{r.slope_after:.4f}, p={r.p_value:.4g})"
    for r in top_sig.itertuples(index=False)
)

top_inc_text = "; ".join(
    f"{r.mode_pool}, cluster {int(r.cluster)} (Δ={r.delta_after_minus_before:+.3f})"
    for r in largest_increase.itertuples(index=False)
)

top_dec_text = "; ".join(
    f"{r.mode_pool}, cluster {int(r.cluster)} (Δ={r.delta_after_minus_before:+.3f})"
    for r in largest_decrease.itertuples(index=False)
)

journal_summary = (
    f"Segmented regression was fitted to {n_models} pool–cluster time series. "
    f"{n_sig} models ({pct_sig:.1f}%) showed statistically significant evidence for a breakpoint (F-test, p<0.05). "
    f"Significance by pool was: {pool_sig_text}. "
    f"The median estimated breakpoint year was {median_bp_all:.1f} overall "
    f"and {median_bp_sig:.1f} among significant fits. "
    f"Slope direction changed across the breakpoint in {n_dir_change}/{n_models} series. "
    f"The strongest significant transitions were: {top_sig_text}. "
    f"\n\nComparing composition before vs. after breakpoints across 23 pool–cluster combinations, "
    f"{n_increase} increased, {n_decrease} decreased, and {n_nochange} were unchanged in proportional representation. "
    f"Largest increases were observed for {top_inc_text}; largest decreases were observed for {top_dec_text}. "
    f"Collectively, these results indicate spatially heterogeneous but measurable temporal reorganization of fish assemblage structure, "
    f"with strongest regime shifts concentrated in specific cluster–pool combinations rather than uniformly across the system."
)

print(journal_summary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 37
#      31 top_sig = sr[sr['significant']].sort_values('p_value').head(3)[
#      32     ['mode_pool', 'cluster', 'breakpoint_year', 'slope_before', 'slope_after', 'p_value']
#      33 ]
#      35 # --- 2) Before vs after proportion shift summary ---
#      36 # wide_df already contains one row per mode_pool-cluster with Before/After proportions
# ---> 37 wd = wide_df.copy()
#      38 wd['delta_after_minus_before'] = wd['After breakpoint'] - wd['Before breakpoint']
#      40 n_increase = int((wd['delta_after_minus_before'] > 0).sum())
#
# NameError: name 'wide_df' is not defined

# %%
df_explore.head()
# Out:
#     barcode     utm_e      utm_n  year     mode_pool  \
# 0  11000330  578229.0  4915808.0  1993  Lower Pool 4
# 1  11000331  579229.0  4916258.0  1993  Lower Pool 4
# 2  11000332  580230.0  4915408.0  1993  Lower Pool 4
# 3  11000333  580880.0  4914858.0  1993  Lower Pool 4
# 4  11000334  581880.0  4913658.0  1993  Lower Pool 4
#
#                mode_aqua_desc   CNCF   LKSG   PDFH   IODR  ...   SJHR   MMSN  \
# 0  Contiguous Floodplain Lake  False  False  False  False  ...  False  False
# 1  Contiguous Floodplain Lake   True  False  False  False  ...  False  False
# 2  Contiguous Floodplain Lake  False  False  False  False  ...   True  False
# 3  Contiguous Floodplain Lake  False  False  False  False  ...  False  False
# 4  Contiguous Floodplain Lake  False  False  False  False  ...  False  False
#
#     RKBS   BSMW   TPMT   BRBT   LSSR   BNMW   WTSK  cluster
# 0  False  False  False  False  False  False  False        2
# 1  False  False  False  False  False  False  False        1
# ...

# %%
# Find the cluster with the largest count
cluster_sizes = df_explore['cluster'].value_counts()
largest_cluster = df_explore['cluster'].value_counts().idxmax()
unique_clusters = sorted(df_explore['cluster'].unique())

# Ensure cluster dtype matches between df_explore and segmented_results_df to avoid merge errors
if 'cluster' in segmented_results_df.columns:
    target_dtype = df_explore['cluster'].dtype
    if segmented_results_df['cluster'].dtype != target_dtype:
        # If df_explore cluster is integer-like, cast segmented_results_df cluster to int
        if np.issubdtype(target_dtype, np.integer):
            segmented_results_df = segmented_results_df.copy()
            segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(int)
        else:
            # otherwise cast to the same dtype as df_explore
            segmented_results_df = segmented_results_df.copy()
            segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(target_dtype)

# Merge breakpoint data with df_explore
df_with_breakpoints = df_explore.merge(
    segmented_results_df[['mode_pool','cluster', 'breakpoint_year']],
    on=['mode_pool', 'cluster'],
    how='left'
)

# Create before/after period column
def assign_period(row):
    if pd.isna(row['breakpoint_year']):
        return 'No breakpoint'
    elif row['year'] <= row['breakpoint_year']:
        return 'Before breakpoint'
    else:
        return 'After breakpoint'

df_with_breakpoints['period'] = df_with_breakpoints.apply(assign_period, axis=1)

# Define clusters to include (use highlight_clusters which is a list)
clusters_to_plot = highlight_clusters  # [1, 2, 3, 4, 5, 6, 7, 8]

# Filter to desired pools and clusters
df_filtered = df_with_breakpoints[
    (df_with_breakpoints['mode_pool'].isin(desired_order)) &
    (df_with_breakpoints['cluster'].isin(clusters_to_plot)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

# Set categorical order for mode_pool
df_filtered['mode_pool'] = pd.Categorical(
    df_filtered['mode_pool'], 
    categories=desired_order, 
    ordered=True
)

# Create FacetGrid with row=mode_pool, col=period
g = sns.FacetGrid(
    df_filtered,
    row="mode_pool",
    col="period",
    hue="cluster",
    palette=color_map,
    height=6,
    aspect=1,
    sharex=False,
    sharey=False
)
g.map_dataframe(sns.scatterplot, x="utm_e", y="utm_n", alpha=0.7, s=50)
g.add_legend(title="Cluster")
g.set_axis_labels("UTM Easting", "UTM Northing")
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.figure.subplots_adjust(top=.94)
g.figure.suptitle("Assemblage Locations Before and After Breakpoint", fontsize=14)
plt.show()
g.figure.savefig('assemblage_location_break.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# Jitterplot

# %%
df_with_breakpoints
# Out:
#        barcode     utm_e      utm_n  year     mode_pool  \
# 0     11000330  578229.0  4915808.0  1993  Lower Pool 4
# 1     11000331  579229.0  4916258.0  1993  Lower Pool 4
# 2     11000332  580230.0  4915408.0  1993  Lower Pool 4
# 3     11000333  580880.0  4914858.0  1993  Lower Pool 4
# 4     11000334  581880.0  4913658.0  1993  Lower Pool 4
# ...        ...       ...        ...   ...           ...
# 2407  13011717  719544.0  4675438.0  2024       Pool 13
# 2408  13011719  716008.0  4677201.0  2024       Pool 13
# 2409  13011720  718008.0  4675851.0  2024       Pool 13
# 2410  13011721  718258.0  4676301.0  2024       Pool 13
# 2411  13011722  713958.0  4679829.0  2024       Pool 13
#
#                    mode_aqua_desc   CNCF   LKSG   PDFH   IODR  ...   RKBS  \
# 0      Contiguous Floodplain Lake  False  False  False  False  ...  False
# 1      Contiguous Floodplain Lake   True  False  False  False  ...  False
# ...

# %%
# Find the cluster with the largest count
cluster_sizes = df_explore['cluster'].value_counts()
largest_cluster = df_explore['cluster'].value_counts().idxmax()
unique_clusters = sorted(df_explore['cluster'].unique())

# Ensure cluster dtype matches between df_explore and segmented_results_df to avoid merge errors
if 'cluster' in segmented_results_df.columns:
    target_dtype = df_explore['cluster'].dtype
    if segmented_results_df['cluster'].dtype != target_dtype:
        # If df_explore cluster is integer-like, cast segmented_results_df cluster to int
        if np.issubdtype(target_dtype, np.integer):
            segmented_results_df = segmented_results_df.copy()
            segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(int)
        else:
            # otherwise cast to the same dtype as df_explore
            segmented_results_df = segmented_results_df.copy()
            segmented_results_df['cluster'] = segmented_results_df['cluster'].astype(target_dtype)

# Merge breakpoint data with df_explore
df_with_breakpoints = df_explore.merge(
    segmented_results_df[['mode_pool', 'cluster', 'breakpoint_year']],
    on=['mode_pool', 'cluster'],
    how='left'
)

# Create before/after period column
def assign_period(row):
    if pd.isna(row['breakpoint_year']):
        return 'No breakpoint'
    elif row['year'] <= row['breakpoint_year']:
        return 'Before breakpoint'
    else:
        return 'After breakpoint'

df_with_breakpoints['period'] = df_with_breakpoints.apply(assign_period, axis=1)

# Define clusters to include (use highlight_clusters which is a list)
clusters_to_plot = highlight_clusters  # [1, 2, 3, 4, 5, 6, 7, 8]

# Filter to desired pools and clusters
df_filtered = df_with_breakpoints[
    (df_with_breakpoints['mode_pool'].isin(desired_order)) &
    (df_with_breakpoints['cluster'].isin(clusters_to_plot)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

# Add jitter to UTM coordinates
# Adjust jitter_amount based on your coordinate scale (UTM is in meters)
jitter_amount = 500  # 500 meters of jitter
np.random.seed(42)  # For reproducibility
df_filtered['utm_e_jitter'] = df_filtered['utm_e'] + np.random.uniform(-jitter_amount, jitter_amount, len(df_filtered))
df_filtered['utm_n_jitter'] = df_filtered['utm_n'] + np.random.uniform(-jitter_amount, jitter_amount, len(df_filtered))

# Set categorical order for mode_pool
df_filtered['mode_pool'] = pd.Categorical(
    df_filtered['mode_pool'], 
    categories=desired_order, 
    ordered=True
)

# Create FacetGrid with row=mode_pool, col=period
g = sns.FacetGrid(
    df_filtered,
    row="mode_pool",
    col="period",
    hue="cluster",
    palette=color_map,
    height=6,
    aspect=1,
    sharex=False,
    sharey=False
)
g.map_dataframe(sns.scatterplot, x="utm_e_jitter", y="utm_n_jitter", alpha=0.7, s=50)
g.add_legend(title="Cluster")
g.set_axis_labels("UTM Easting", "UTM Northing")
g.set_titles(row_template="{row_name}", col_template="{col_name}")
g.figure.subplots_adjust(top=.94)
g.figure.suptitle("Assemblage Locations Before and After Breakpoint", fontsize=14)
plt.show()
g.figure.savefig('assemblage_location_break.jpg', dpi=300, bbox_inches='tight')

# %%
import tol_colors as tc

# Define clusters to show
highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8]

# Define pool order
pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

# Build color palette from tol_colors muted
CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# Filter data to highlight clusters only and exclude 'No breakpoint'
df_plot = df_with_breakpoints[
    (df_with_breakpoints['cluster'].isin(highlight_clusters)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

# Create plots for each period
for period in ['Before breakpoint', 'After breakpoint']:
    # Filter for this period
    df_period = df_plot[df_plot['period'] == period].copy()
    
    # Calculate proportion of samples in each pool for each cluster
    prop_df = (df_period.groupby(['mode_pool', 'cluster'])
               .size()
               .reset_index(name='count'))
    
    # Calculate total samples per pool to get proportions
    totals = prop_df.groupby('mode_pool')['count'].transform('sum')
    prop_df['proportion'] = prop_df['count'] / totals
    
    # Set cluster as categorical with numerical order
    prop_df['cluster'] = pd.Categorical(prop_df['cluster'], categories=highlight_clusters, ordered=True)
    
    # Create plot
    plt.figure(figsize=(12, 6))
    sns.barplot(data=prop_df, x='mode_pool', y='proportion', hue='cluster',
                palette=cluster_colors, dodge=True, 
                order=pool_order,
                hue_order=highlight_clusters)
    
    plt.xlabel('Pool')
    plt.ylabel('Proportion of Samples')
    plt.title(f'Proportion of Samples by Pool and Cluster - {period}')
    plt.legend(title='Cluster', bbox_to_anchor=(1.02, 0.5), loc='center left')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    
    # Create filename based on period
    filename = f"cluster_pool_proportion_{period.lower().replace(' ', '_')}.jpg"
    plt.savefig(
        filename,
        dpi=300,
        bbox_inches='tight',
        format='jpeg',
        pil_kwargs={'quality': 95, 'optimize': True, 'progressive': True}
    )
    
    plt.show()

# %%
import tol_colors as tc

highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8]
pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# Filter data
df_plot = df_with_breakpoints[
    (df_with_breakpoints['cluster'].isin(highlight_clusters)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

# Calculate proportions for both periods
prop_df = (df_plot.groupby(['mode_pool', 'cluster', 'period'])
           .size()
           .reset_index(name='count'))
totals = prop_df.groupby(['mode_pool', 'period'])['count'].transform('sum')
prop_df['proportion'] = prop_df['count'] / totals

prop_df['cluster'] = pd.Categorical(prop_df['cluster'], categories=highlight_clusters, ordered=True)
prop_df['mode_pool'] = pd.Categorical(prop_df['mode_pool'], categories=pool_order, ordered=True)
prop_df['period'] = pd.Categorical(prop_df['period'], 
                                    categories=['Before breakpoint', 'After breakpoint'], 
                                    ordered=True)

# Create faceted plot
g = sns.FacetGrid(prop_df, col='period', height=5, aspect=1.2, sharey=True)
g.map_dataframe(sns.barplot, x='mode_pool', y='proportion', hue='cluster',
                palette=cluster_colors, dodge=True, order=pool_order,
                hue_order=highlight_clusters)

g.set_axis_labels('Pool', 'Proportion of Samples')
g.set_titles(col_template='{col_name}')
g.add_legend(title='Cluster', bbox_to_anchor=(1.02, 0.5), loc='center left')

for ax in g.axes.flat:
    ax.tick_params(axis='x', rotation=45)
    for label in ax.get_xticklabels():
        label.set_ha('right')

plt.tight_layout()
plt.savefig('cluster_pool_proportion_comparison.jpg', dpi=300, bbox_inches='tight',
            format='jpeg', pil_kwargs={'quality': 95})
plt.show()

# %%
import tol_colors as tc
import matplotlib.lines as mlines

highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8]
pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

df_plot = df_with_breakpoints[
    (df_with_breakpoints['cluster'].isin(highlight_clusters)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

prop_df = (df_plot.groupby(['mode_pool', 'cluster', 'period'])
           .size()
           .reset_index(name='count'))
totals = prop_df.groupby(['mode_pool', 'period'])['count'].transform('sum')
prop_df['proportion'] = prop_df['count'] / totals

# Pivot for before/after comparison
wide_df = prop_df.pivot_table(index=['mode_pool', 'cluster'], 
                               columns='period', values='proportion').reset_index()
wide_df.columns.name = None

fig, axes = plt.subplots(2, 2, figsize=(12, 10), sharey=True)
axes = axes.flatten()

for idx, pool in enumerate(pool_order):
    ax = axes[idx]
    pool_data = wide_df[wide_df['mode_pool'] == pool]
    
    for _, row in pool_data.iterrows():
        cluster = row['cluster']
        color = cluster_colors.get(cluster, 'gray')
        before = row.get('Before breakpoint', None)
        after = row.get('After breakpoint', None)

        if pd.notna(before) and pd.notna(after):
            ax.plot([0, 1], [before, after],
                    marker='o', color=color, linewidth=2, markersize=8)

    ax.set_xticks([0, 1])
    ax.set_xticklabels(['Before', 'After'])
    ax.set_title(pool)
    ax.set_ylabel('Proportion' if idx % 2 == 0 else '')
    ax.set_xlim(-0.2, 1.2)

# Build legend manually — guarantees all clusters are always included
handles = [
    mlines.Line2D([0], [0], color=cluster_colors[c], marker='o',
                  linewidth=2, markersize=8, label=f'Cluster {c}')
    for c in highlight_clusters
]

fig.legend(handles=handles, loc='center right', bbox_to_anchor=(1.12, 0.5), title='Cluster')
plt.suptitle('Change in Cluster Proportions Before vs After Breakpoint', fontsize=14)
plt.tight_layout()
plt.savefig('cluster_change_pool_slopegraph.jpg', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import tol_colors as tc

# -----------------------------
# Config
# -----------------------------
highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8]
pool_order = ["Upper Pool 4", "Lower Pool 4", "Pool 8", "Pool 13"]

CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# -----------------------------
# 1) Annual cluster proportion within each pool
#    proportion = (cluster count in pool-year) / (total count in pool-year)
# -----------------------------
df_plot = df_with_breakpoints[
    (df_with_breakpoints["period"] != "No breakpoint") &
    (df_with_breakpoints["cluster"].isin(highlight_clusters)) &
    (df_with_breakpoints["mode_pool"].isin(pool_order))
].copy()

annual_cluster = (
    df_plot.groupby(["mode_pool", "year", "cluster", "period"], as_index=False)
    .size()
    .rename(columns={"size": "n_cluster"})
)

annual_total = (
    df_plot.groupby(["mode_pool", "year"], as_index=False)
    .size()
    .rename(columns={"size": "n_total"})
)

annual_prop = annual_cluster.merge(annual_total, on=["mode_pool", "year"], how="left")
annual_prop["proportion"] = annual_prop["n_cluster"] / annual_prop["n_total"]

# -----------------------------
# 2) Average annual proportion by period (Before vs After breakpoint)
# -----------------------------
avg_prop = (
    annual_prop.groupby(["mode_pool", "cluster", "period"], as_index=False)["proportion"]
    .mean()
)

wide_df = avg_prop.pivot_table(
    index=["mode_pool", "cluster"],
    columns="period",
    values="proportion",
    aggfunc="mean"
).reset_index()

# Ensure integer cluster for color map
wide_df["cluster"] = wide_df["cluster"].astype(int)

# -----------------------------
# 3) Slopegraph panels by pool
# -----------------------------
fig, axes = plt.subplots(2, 2, figsize=(12, 10), sharey=True)
axes = axes.flatten()

for i, pool in enumerate(pool_order):
    ax = axes[i]
    pool_data = wide_df[wide_df["mode_pool"] == pool].copy()

    for _, row in pool_data.iterrows():
        c = row["cluster"]
        before = row.get("Before breakpoint", np.nan)
        after = row.get("After breakpoint", np.nan)
        color = cluster_colors.get(c, "gray")

        # Draw slope only when both sides exist
        if pd.notna(before) and pd.notna(after):
            ax.plot([0, 1], [before, after], marker="o", color=color, linewidth=2, markersize=7)
        elif pd.notna(before):
            ax.plot(0, before, marker="o", color=color, markersize=7)
        elif pd.notna(after):
            ax.plot(1, after, marker="o", color=color, markersize=7)

    ax.set_xticks([0, 1])
    ax.set_xticklabels(["Before", "After"])
    ax.set_title(pool)
    ax.set_xlim(-0.2, 1.2)
    if i % 2 == 0:
        ax.set_ylabel("Average annual cluster proportion")

# Legend
handles = [
    mlines.Line2D([0], [0], color=cluster_colors[c], marker="o", linewidth=2, markersize=7, label=f"Cluster {c}")
    for c in highlight_clusters
]
fig.legend(handles=handles, loc="center right", bbox_to_anchor=(1.12, 0.5), title="Cluster")

plt.suptitle("Average Cluster Proportion Before vs After Breakpoint by Mode Pool", fontsize=14)
plt.tight_layout()
plt.savefig("cluster_avg_proportion_pool_slopegraph.jpg", dpi=300, bbox_inches="tight")
plt.show()

# %%
import tol_colors as tc

highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8]

CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# Filter data
df_plot = df_with_breakpoints[
    (df_with_breakpoints['cluster'].isin(highlight_clusters)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

# Calculate proportions for both periods
prop_df = (df_plot.groupby(['mode_aqua_desc', 'cluster', 'period'])
           .size()
           .reset_index(name='count'))
totals = prop_df.groupby(['mode_aqua_desc', 'period'])['count'].transform('sum')
prop_df['proportion'] = prop_df['count'] / totals

prop_df['cluster'] = pd.Categorical(prop_df['cluster'], categories=highlight_clusters, ordered=True)
prop_df['mode_aqua_desc'] = pd.Categorical(prop_df['mode_aqua_desc'])
prop_df['period'] = pd.Categorical(prop_df['period'], 
                                    categories=['Before breakpoint', 'After breakpoint'], 
                                    ordered=True)

# Create faceted plot
g = sns.FacetGrid(prop_df, col='period', height=5, aspect=1.2, sharey=True)
g.map_dataframe(sns.barplot, x='mode_aqua_desc', y='proportion', hue='cluster',
                palette=cluster_colors, dodge=True,
                hue_order=highlight_clusters)

g.set_axis_labels('Aquatic Description', 'Proportion of Samples')
g.set_titles(col_template='{col_name}')
g.add_legend(title='Cluster', bbox_to_anchor=(1.02, 0.5), loc='center left')

for ax in g.axes.flat:
    ax.tick_params(axis='x', rotation=45)
    for label in ax.get_xticklabels():
        label.set_ha('right')

plt.tight_layout()
plt.savefig('cluster_aqua_proportion_comparison.jpg', dpi=300, bbox_inches='tight',
            format='jpeg', pil_kwargs={'quality': 95})
plt.show()

# %%
import tol_colors as tc
import math
import matplotlib.lines as mlines

highlight_clusters = [1, 2, 3, 4, 5, 6, 7, 8]

CB_PALETTE = tc.muted
cluster_colors = {c: CB_PALETTE[i % len(CB_PALETTE)] for i, c in enumerate(highlight_clusters)}

# Filter data
df_plot = df_with_breakpoints[
    (df_with_breakpoints['cluster'].isin(highlight_clusters)) &
    (df_with_breakpoints['period'] != 'No breakpoint')
].copy()

# Calculate proportions grouped by aqua_desc
prop_df = (df_plot.groupby(['mode_aqua_desc', 'cluster', 'period'])
           .size()
           .reset_index(name='count'))
totals = prop_df.groupby(['mode_aqua_desc', 'period'])['count'].transform('sum')
prop_df['proportion'] = prop_df['count'] / totals

# Pivot for before/after comparison
wide_df = prop_df.pivot_table(index=['mode_aqua_desc', 'cluster'],
                               columns='period', values='proportion').reset_index()
wide_df.columns.name = None

handles = [
    mlines.Line2D([0], [0], color=cluster_colors[c], marker='o',
                  linewidth=2, markersize=8, label=f'Cluster {c}')
    for c in highlight_clusters
]

# Dynamically determine subplot layout
aqua_desc_order = sorted(df_plot['mode_aqua_desc'].dropna().unique())
n_panels = len(aqua_desc_order)
n_cols = 3
n_rows = math.ceil(n_panels / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4.5), sharey=True)
axes = axes.flatten()

for idx, aqua_desc in enumerate(aqua_desc_order):
    ax = axes[idx]
    panel_data = wide_df[wide_df['mode_aqua_desc'] == aqua_desc]

    for _, row in panel_data.iterrows():
        cluster = row['cluster']
        color = cluster_colors.get(cluster, 'gray')
        before = row.get('Before breakpoint', None)
        after = row.get('After breakpoint', None)

        if pd.notna(before) and pd.notna(after):
            ax.plot([0, 1], [before, after],
                    marker='o', color=color, linewidth=2, markersize=8,
                    label=f'Cluster {cluster}')

    ax.set_xticks([0, 1])
    ax.set_xticklabels(['Before', 'After'])
    ax.set_title(aqua_desc, fontsize=10)
    ax.set_ylabel('Proportion' if idx % n_cols == 0 else '')
    ax.set_xlim(-0.2, 1.2)

# Hide any unused subplots
for idx in range(n_panels, len(axes)):
    axes[idx].set_visible(False)

# Place legend below the figure, horizontally centered
fig.legend(handles=handles,
           loc='upper center',
           bbox_to_anchor=(0.5, 0.0),   # centered, just below figure
           ncol=len(highlight_clusters), # all clusters in one row
           title='Cluster',
           frameon=True)

plt.suptitle('Change in Cluster Proportions Before vs After Breakpoint\nby Aquatic Description',
             fontsize=14)

# Reserve space at bottom for the legend
plt.tight_layout()
plt.subplots_adjust(bottom=0.08)

plt.savefig('cluster_aqua_slopegraph.jpg', dpi=300, bbox_inches='tight')
plt.show()
